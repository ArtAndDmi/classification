# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from src.eda import *
from src.consts import *

# %%
df = pd.read_csv(DATA_PATH)

df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
run_data_quality_report(df)
# Out:
# ...
# DATA QUALITY REPORT
# ...
# Shape: (48842, 15)
#
# Dtypes:
#  age                int64
# workclass            str
# fnlwgt             int64
# education            str
# educational-num    int64
# marital-status       str
# occupation           str
# relationship         str
# race                 str
# gender               str
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country       str
# income               str
# dtype: object
#
# Missing values:
#                  missing  missing_%
# age                    0        0.0
# workclass              0        0.0
# fnlwgt                 0        0.0
# education              0        0.0
# educational-num        0        0.0
# marital-status         0        0.0
# occupation             0        0.0
# relationship           0        0.0
# race                   0        0.0
# gender                 0        0.0
# capital-gain           0        0.0
# capital-loss           0        0.0
# ...

# %%
feature_summary_report(df)
# Out:
# ...
# FEATURE SUMMARY REPORT
# ...
#
# NUMERIC FEATURES:
#             feature  dtype  missing_%  nunique example_value
# 0               age  int64        0.0       74            25
# 2            fnlwgt  int64        0.0    28523        226802
# 4   educational-num  int64        0.0       16             7
# 10     capital-gain  int64        0.0      123             0
# 11     capital-loss  int64        0.0       99             0
# 12   hours-per-week  int64        0.0       96            40
#
# CATEGORICAL FEATURES:
#            feature dtype  missing_%  nunique      example_value
# 1        workclass   str        0.0        9            Private
# 3        education   str        0.0       16               11th
# 5   marital-status   str        0.0        7      Never-married
# 6       occupation   str        0.0       15  Machine-op-inspct
# 7     relationship   str        0.0        6          Own-child
# 8             race   str        0.0        5              Black
# ...

# %%
analyze_numeric(df['age'])
# Out:
# ...
# NUMERIC FEATURE: age
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         74
#
# Statistics:
# count    48842.000000
# mean        38.643585
# std         13.710510
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64
#
# Median:         37.0000
# Skewness:       0.5576
# Kurtosis:       -0.1843

# %%
analyze_numeric(df['fnlwgt'])
# Out:
# ...
# NUMERIC FEATURE: fnlwgt
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         28523
#
# Statistics:
# count    4.884200e+04
# mean     1.896641e+05
# std      1.056040e+05
# min      1.228500e+04
# 25%      1.175505e+05
# 50%      1.781445e+05
# 75%      2.376420e+05
# max      1.490400e+06
# Name: fnlwgt, dtype: float64
#
# Median:         178144.5000
# Skewness:       1.4389
# Kurtosis:       6.0578

# %%
analyze_numeric(df['educational-num'])
# Out:
# ...
# NUMERIC FEATURE: educational-num
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         16
#
# Statistics:
# count    48842.000000
# mean        10.078089
# std          2.570973
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: educational-num, dtype: float64
#
# Median:         10.0000
# Skewness:       -0.3165
# Kurtosis:       0.6257

# %%
analyze_numeric(df['capital-gain'])
print((df['capital-gain'] == 0).sum())
# Out:
# ...
# NUMERIC FEATURE: capital-gain
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         123
#
# Statistics:
# count    48842.000000
# mean      1079.067626
# std       7452.019058
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capital-gain, dtype: float64
#
# Median:         0.0000
# Skewness:       11.8947
# Kurtosis:       152.6931
# 44807

# %%
analyze_numeric(df['capital-loss'])
print((df['capital-loss'] == 0).sum())
# Out:
# ...
# NUMERIC FEATURE: capital-loss
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         99
#
# Statistics:
# count    48842.000000
# mean        87.502314
# std        403.004552
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       4356.000000
# Name: capital-loss, dtype: float64
#
# Median:         0.0000
# Skewness:       4.5698
# Kurtosis:       20.0143
# 46560

# %%
analyze_numeric(df['hours-per-week'])
# Out:
# ...
# NUMERIC FEATURE: hours-per-week
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         96
#
# Statistics:
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64
#
# Median:         40.0000
# Skewness:       0.2387
# Kurtosis:       2.9511
# 0

# %%
df.sort_values('hours-per-week')
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 25428   75             ?  260543        10th                6
# 39241   21       Private  184135     HS-grad                9
# 36031   23       Private   72887     HS-grad                9
# 48806   81             ?  120478   Assoc-voc               11
# 2655    54             ?  186565     Masters               14
# ...    ...           ...     ...         ...              ...
# 15909   41             ?  173651  Assoc-acdm               12
# 31741   37       Private  241174   Bachelors               13
# 36012   34   Federal-gov  345259   Doctorate               16
# 40764   39  Self-emp-inc  124685     Masters               14
# 47273   40  Self-emp-inc  104235     Masters               14
#
#            marital-status         occupation    relationship  \
# 25428             Widowed                  ?  Other-relative
# 39241       Never-married  Machine-op-inspct       Own-child
# ...

# %%
analyze_categorical(df['workclass'])
# Out:
# ...
# CATEGORICAL FEATURE: workclass
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         9
#
# Top values:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64
#
# Top values (%):
# workclass
# Private             69.419762
# Self-emp-not-inc     7.907129
# Local-gov            6.420703
# ?                    5.730724
# State-gov            4.055935
# Self-emp-inc         3.470374
# Federal-gov          2.931903
# Without-pay          0.042996
# Never-worked         0.020474
# Name: proportion, dtype: float64

# %%
analyze_categorical(df['education'])
# Out:
# ...
# CATEGORICAL FEATURE: education
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         16
#
# Top values:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64
#
# Top values (%):
# education
# HS-grad         32.316449
# Some-college    22.271815
# Bachelors       16.430531
# Masters          5.439990
# Assoc-voc        4.219729
# 11th             3.709922
# Assoc-acdm       3.277917
# 10th             2.843864
# 7th-8th          1.955284
# Prof-school      1.707547
# 9th              1.547848
# 12th             1.345154
# Doctorate        1.216166
# 5th-6th          1.042136
# ...

# %%
analyze_categorical(df['marital-status'])
# Out:
# ...
# CATEGORICAL FEATURE: marital-status
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         7
#
# Top values:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64
#
# Top values (%):
# marital-status
# Married-civ-spouse       45.819172
# Never-married            32.998239
# Divorced                 13.580525
# Separated                 3.132550
# Widowed                   3.107981
# Married-spouse-absent     1.285779
# Married-AF-spouse         0.075754
# Name: proportion, dtype: float64

# %%
analyze_categorical(df['occupation'])
# Out:
# ...
# CATEGORICAL FEATURE: occupation
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         15
#
# Top values:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64
#
# Top values (%):
# occupation
# Prof-specialty       12.636665
# Craft-repair         12.513820
# Exec-managerial      12.460587
# Adm-clerical         11.488064
# Sales                11.268990
# Other-service        10.079440
# Machine-op-inspct     6.187298
# ?                     5.751198
# Transport-moving      4.821670
# Handlers-cleaners     4.242251
# Farming-fishing       3.050653
# ...

# %%
analyze_categorical(df['relationship'])
# Out:
# ...
# CATEGORICAL FEATURE: relationship
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         6
#
# Top values:
# relationship
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: count, dtype: int64
#
# Top values (%):
# relationship
# Husband           40.366897
# Not-in-family     25.762663
# Own-child         15.521477
# Unmarried         10.493018
# Wife               4.772532
# Other-relative     3.083412
# Name: proportion, dtype: float64

# %%
analyze_categorical(df['race'])
# Out:
# ...
# CATEGORICAL FEATURE: race
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         5
#
# Top values:
# race
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: count, dtype: int64
#
# Top values (%):
# race
# White                 85.504279
# Black                  9.592154
# Asian-Pac-Islander     3.110028
# Amer-Indian-Eskimo     0.962287
# Other                  0.831252
# Name: proportion, dtype: float64

# %%
analyze_categorical(df['gender'])
# Out:
# ...
# CATEGORICAL FEATURE: gender
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         2
#
# Top values:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64
#
# Top values (%):
# gender
# Male      66.848204
# Female    33.151796
# Name: proportion, dtype: float64

# %%
analyze_categorical(df['native-country'])
# Out:
# ...
# CATEGORICAL FEATURE: native-country
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         42
#
# Top values:
# native-country
# United-States         43832
# Mexico                  951
# ?                       857
# Philippines             295
# Germany                 206
# Puerto-Rico             184
# Canada                  182
# El-Salvador             155
# India                   151
# Cuba                    138
# England                 127
# China                   122
# South                   115
# Jamaica                 106
# Italy                   105
# Dominican-Republic      103
# Japan                    92
# Guatemala                88
# Poland                   87
# Vietnam                  86
# Name: count, dtype: int64
#
# Top values (%):
# native-country
# United-States         89.742435
# Mexico                 1.947095
# ?                      1.754637
# Philippines            0.603988
# Germany                0.421768
# ...

# %%
analyze_categorical(df['income'])
# Out:
# ...
# CATEGORICAL FEATURE: income
# ...
# Count:          48842
# Missing:        0
# Missing %:      0.00%
# Unique:         2
#
# Top values:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64
#
# Top values (%):
# income
# <=50K    76.071823
# >50K     23.928177
# Name: proportion, dtype: float64

# %%
plot_classification_correlation_heatmap(df, TARGET, '>50K', 10)
# Out:
# Skipped high-cardinality categorical columns:
# ['education', 'occupation', 'native-country']
